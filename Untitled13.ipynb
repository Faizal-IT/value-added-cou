# %%
pip install bs4

# %%
pip install requests
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from bs4 import BeautifulSoup

# %%
import requests

# %%
url="https://www.flipkart.com/gaming/pr?sid=4rr&fm=neo%2Fmerchandising&iid=M_a88f21b5-6914-4ed9-a8cb-24c3c03252fa_1_372UD5BXDFYS_MC.PK7I48M403OR&otracker=hp_rich_navigation_5_1.navigationCard.RICH_NAVIGATION_Electronics~Gaming_PK7I48M403OR&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_5_L1_view-all&cid=PK7I48M403OR&p%5B%5D=facets.brand%255B%255D%3DASUS&p%5B%5D=facets.rating%255B%255D%3D4%25E2%2598%2585%2B%2526%2Babove"

# %%
url
# Out:
# 'https://www.flipkart.com/gaming/pr?sid=4rr&fm=neo%2Fmerchandising&iid=M_a88f21b5-6914-4ed9-a8cb-24c3c03252fa_1_372UD5BXDFYS_MC.PK7I48M403OR&otracker=hp_rich_navigation_5_1.navigationCard.RICH_NAVIGATION_Electronics~Gaming_PK7I48M403OR&otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_5_L1_view-all&cid=PK7I48M403OR&p%5B%5D=facets.brand%255B%255D%3DASUS&p%5B%5D=facets.rating%255B%255D%3D4%25E2%2598%2585%2B%2526%2Babove'

# %%
allow=requests.get(url)

# %%
allow
# Out:
# <Response [200]>

# %%
soup=BeautifulSoup(allow.text)

# %%
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
lap_name=soup.select(".s1Q9rs")

# %%
lap_name
# Out:
# [<a class="s1Q9rs" href="/asus-tuf-gaming-a17-ryzen-7-octa-core-4800h-16-gb-512-gb-ssd-windows-10-home-4-graphics-nvidia-geforce-rtx-3050-fa706ic-hx003t-laptop/p/itmccc79bbd17e07?pid=COMG8N5PFPCX9Z3J&amp;lid=LSTCOMG8N5PFPCX9Z3JGKCEFC&amp;marketplace=FLIPKART&amp;store=4rr&amp;srno=b_1_1&amp;otracker=hp_rich_navigation_5_1.navigationCard.RICH_NAVIGATION_Electronics~Gaming_PK7I48M403OR&amp;otracker1=hp_rich_navigation_PINNED_neo%2Fmerchandising_NA_NAV_EXPANDABLE_navigationCard_cc_5_L1_view-all&amp;fm=organic&amp;iid=ae572663-3745-4426-910e-b0552a7c7447.COMG8N5PFPCX9Z3J.SEARCH&amp;ppt=None&amp;ppn=None&amp;ssid=a9wpu4lwvk0000001653230043565" rel="noopener noreferrer" target="_blank" title="ASUS ASUS TUF Gaming A17 Ryzen 7 Octa Core 4800H - (16 GB/512 GB SSD/Windows 10 Home/4 GB Graphics/NVIDIA GeForce RTX 3050) FA706IC-HX003T Gaming Laptop">ASUS ASUS TUF Gaming A17 Ryzen 7 Octa Core 4800H - (16 ...</a>,
# ...

# %%
laptop_names=[]

# %%
for i in lap_name:
    laptop_names.append(i.text)

# %%
laptop_names
# Out:
# ['ASUS ASUS TUF Gaming A17 Ryzen 7 Octa Core 4800H - (16 ...',
#  'ASUS ASUS TUF Gaming Core i5 11th Gen - (8 GB/1 TB SSD/...',
#  'ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD...',
#  'ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD...',
#  'ASUS ROG Strix G15 Ryzen 7 Octa Core 4800H - (8 GB/512 ...',
#  'ASUS ROG Strix G15 Ryzen 9 Octa Core 5900HX - (16 GB/1 ...',
#  'ASUS ASUS TUF Dash F15 Core i5 11th Gen - (16 GB/512 GB...',
#  'ASUS TUF M3 Wired Optical  Gaming Mouse',
#  'ASUS Vivobook Gaming Core i7 10th Gen - (16 GB/512 GB S...',
#  'ASUS ROG Strix G15 Core i7 10th Gen - (16 GB/512 GB SSD...',
#  'ASUS ROG Strix G15 Ryzen 7 Octa Core 6800H - (16 GB/1 T...',
#  'ASUS ASUS TUF Gaming Ryzen 7 Octa Core 4800H - (16 GB/5...',
#  'ASUS Vivobook Gaming Core i7 10th Gen - (16 GB/1 TB HDD...',
#  'ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/512 GB SSD...',
#  'ASUS ROG Strix G15 (2021) Ryzen 7 Octa Core 4800H - (8 ...',
# ...

# %%
lap_price=soup.select("._30jeq3")

# %%
lap_price
# Out:
# [<div class="_30jeq3">₹79,990</div>,
#  <div class="_30jeq3">₹75,990</div>,
#  <div class="_30jeq3">₹59,990</div>,
#  <div class="_30jeq3">₹62,800</div>,
#  <div class="_30jeq3">₹83,990</div>,
#  <div class="_30jeq3">₹1,35,990</div>,
#  <div class="_30jeq3">₹84,990</div>,
#  <div class="_30jeq3">₹1,589</div>,
#  <div class="_30jeq3">₹67,990</div>,
#  <div class="_30jeq3">₹84,990</div>,
#  <div class="_30jeq3">₹1,14,990</div>,
#  <div class="_30jeq3">₹80,990</div>,
#  <div class="_30jeq3">₹68,990</div>,
#  <div class="_30jeq3">₹65,990</div>,
#  <div class="_30jeq3">₹76,990</div>,
#  <div class="_30jeq3">₹78,990</div>,
#  <div class="_30jeq3">₹82,990</div>,
#  <div class="_30jeq3">₹89,990</div>,
#  <div class="_30jeq3">₹6,900</div>,
#  <div class="_30jeq3">₹1,39,990</div>,
#  <div class="_30jeq3">₹6,320</div>,
#  <div class="_30jeq3">₹94,990</div>,
#  <div class="_30jeq3">₹92,590</div>,
#  <div class="_30jeq3">₹97,990</div>,
#  <div class="_30jeq3">₹70,990</div>,
# ...

# %%
laptop_price=[]

# %%
for i in lap_price:
    laptop_price.append(i.text)

# %%
laptop_price
# Out:
# ['₹79,990',
#  '₹75,990',
#  '₹59,990',
#  '₹62,800',
#  '₹83,990',
#  '₹1,35,990',
#  '₹84,990',
#  '₹1,589',
#  '₹67,990',
#  '₹84,990',
#  '₹1,14,990',
#  '₹80,990',
#  '₹68,990',
#  '₹65,990',
#  '₹76,990',
#  '₹78,990',
#  '₹82,990',
#  '₹89,990',
#  '₹6,900',
#  '₹1,39,990',
#  '₹6,320',
#  '₹94,990',
#  '₹92,590',
#  '₹97,990',
#  '₹70,990',
#  '₹54,890',
#  '₹1,09,990',
#  '₹54,990',
#  '₹63,990',
#  '₹63,580',
#  '₹1,09,990',
#  '₹1,54,990',
#  '₹2,34,990',
#  '₹62,990',
#  '₹87,490',
#  '₹1,41,990',
#  '₹2,790',
#  '₹66,890',
#  '₹63,990',
#  '₹57,990']

# %%
lap_rating=soup.select("._3LWZlK")

# %%
lap_rating
# Out:
# [<div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.6<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.9<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.7<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.1<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.8<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.5<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.2<img class="_1wB99o" src="..."/></div>,
#  <div class="_3LWZlK">4.4<img class="_1wB99o" src="..."/></div>,
# ...

# %%
laptop_rate=[]

# %%
for j in lap_rating:
    laptop_rate.append(j.text)

# %%
laptop_rate
# Out:
# ['4.5',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4.6',
#  '4.1',
#  '4.9',
#  '4.7',
#  '4.1',
#  '4.5',
#  '4.8',
#  '4.5',
#  '4.2',
#  '4.4',
#  '4.5',
#  '4.5',
#  '4.5',
#  '4.6',
#  '4.6',
#  '4.3',
#  '4.6',
#  '4.5',
#  '4.6',
#  '4.7',
#  '4.5',
#  '4.4',
#  '4.5',
#  '4.3',
#  '4.5',
#  '4.7',
#  '4.4',
#  '4.6',
#  '5',
#  '4.4',
#  '4.4',
#  '4.2',
#  '4.6',
#  '4.4',
#  '4.4',
#  '4.3']

# %%
lap_discount=soup.select("._3Ay6Sb")

# %%
lap_discount
# Out:
# [<div class="_3Ay6Sb"><span>25% off</span></div>,
#  <div class="_3Ay6Sb"><span>35% off</span></div>,
#  <div class="_3Ay6Sb"><span>26% off</span></div>,
#  <div class="_3Ay6Sb"><span>20% off</span></div>,
#  <div class="_3Ay6Sb"><span>22% off</span></div>,
#  <div class="_3Ay6Sb"><span>26% off</span></div>,
#  <div class="_3Ay6Sb"><span>34% off</span></div>,
#  <div class="_3Ay6Sb"><span>36% off</span></div>,
#  <div class="_3Ay6Sb"><span>28% off</span></div>,
#  <div class="_3Ay6Sb"><span>2% off</span></div>,
#  <div class="_3Ay6Sb"><span>19% off</span></div>,
#  <div class="_3Ay6Sb"><span>25% off</span></div>,
#  <div class="_3Ay6Sb"><span>29% off</span></div>,
#  <div class="_3Ay6Sb"><span>26% off</span></div>,
#  <div class="_3Ay6Sb"><span>15% off</span></div>,
#  <div class="_3Ay6Sb"><span>31% off</span></div>,
#  <div class="_3Ay6Sb"><span>23% off</span></div>,
#  <div class="_3Ay6Sb"><span>30% off</span></div>,
#  <div class="_3Ay6Sb"><span>13% off</span></div>,
# ...

# %%
laptop_offer=[]

# %%
for i in lap_discount:
    laptop_offer.append(i.text)

# %%
laptop_offer
# Out:
# ['25% off',
#  '35% off',
#  '26% off',
#  '20% off',
#  '22% off',
#  '26% off',
#  '34% off',
#  '36% off',
#  '28% off',
#  '2% off',
#  '19% off',
#  '25% off',
#  '29% off',
#  '26% off',
#  '15% off',
#  '31% off',
#  '23% off',
#  '30% off',
#  '13% off',
#  '25% off',
#  '20% off',
#  '6% off',
#  '20% off',
#  '28% off',
#  '21% off',
#  '30% off',
#  '23% off',
#  '28% off',
#  '28% off',
#  '21% off',
#  '37% off',
#  '25% off',
#  '18% off',
#  '23% off',
#  '16% off',
#  '25% off',
#  '11% off',
#  '14% off',
#  '24% off',
#  '25% off']

# %%
import pandas as pd

# %%
Laptop=pd.DataFrame(laptop_names,columns=["laptop"])

# %%
Laptop
# Out:
#                                                laptop
# 0   ASUS ASUS TUF Gaming A17 Ryzen 7 Octa Core 480...
# 1   ASUS ASUS TUF Gaming Core i5 11th Gen - (8 GB/...
# 2   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...
# 3   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...
# 4   ASUS ROG Strix G15 Ryzen 7 Octa Core 4800H - (...
# 5   ASUS ROG Strix G15 Ryzen 9 Octa Core 5900HX - ...
# 6   ASUS ASUS TUF Dash F15 Core i5 11th Gen - (16 ...
# 7             ASUS TUF M3 Wired Optical  Gaming Mouse
# 8   ASUS Vivobook Gaming Core i7 10th Gen - (16 GB...
# 9   ASUS ROG Strix G15 Core i7 10th Gen - (16 GB/5...
# 10  ASUS ROG Strix G15 Ryzen 7 Octa Core 6800H - (...
# 11  ASUS ASUS TUF Gaming Ryzen 7 Octa Core 4800H -...
# 12  ASUS Vivobook Gaming Core i7 10th Gen - (16 GB...
# 13  ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...
# 14  ASUS ROG Strix G15 (2021) Ryzen 7 Octa Core 48...
# 15  ASUS TUF Gaming F17 (2021) Core i5 11th Gen - ...
# ...

# %%
Laptop["price"]=laptop_price

# %%
Laptop
# Out:
#                                                laptop      price
# 0   ASUS ASUS TUF Gaming A17 Ryzen 7 Octa Core 480...    ₹79,990
# 1   ASUS ASUS TUF Gaming Core i5 11th Gen - (8 GB/...    ₹75,990
# 2   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...    ₹59,990
# 3   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...    ₹62,800
# 4   ASUS ROG Strix G15 Ryzen 7 Octa Core 4800H - (...    ₹83,990
# 5   ASUS ROG Strix G15 Ryzen 9 Octa Core 5900HX - ...  ₹1,35,990
# 6   ASUS ASUS TUF Dash F15 Core i5 11th Gen - (16 ...    ₹84,990
# 7             ASUS TUF M3 Wired Optical  Gaming Mouse     ₹1,589
# 8   ASUS Vivobook Gaming Core i7 10th Gen - (16 GB...    ₹67,990
# 9   ASUS ROG Strix G15 Core i7 10th Gen - (16 GB/5...    ₹84,990
# 10  ASUS ROG Strix G15 Ryzen 7 Octa Core 6800H - (...  ₹1,14,990
# 11  ASUS ASUS TUF Gaming Ryzen 7 Octa Core 4800H -...    ₹80,990
# 12  ASUS Vivobook Gaming Core i7 10th Gen - (16 GB...    ₹68,990
# ...

# %%
Laptop["rating"]=laptop_rate

# %%
Laptop
# Out:
#                                                laptop      price rating
# 0   ASUS ASUS TUF Gaming A17 Ryzen 7 Octa Core 480...    ₹79,990    4.5
# 1   ASUS ASUS TUF Gaming Core i5 11th Gen - (8 GB/...    ₹75,990    4.5
# 2   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...    ₹59,990    4.5
# 3   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...    ₹62,800    4.5
# 4   ASUS ROG Strix G15 Ryzen 7 Octa Core 4800H - (...    ₹83,990    4.6
# 5   ASUS ROG Strix G15 Ryzen 9 Octa Core 5900HX - ...  ₹1,35,990    4.1
# 6   ASUS ASUS TUF Dash F15 Core i5 11th Gen - (16 ...    ₹84,990    4.9
# 7             ASUS TUF M3 Wired Optical  Gaming Mouse     ₹1,589    4.7
# 8   ASUS Vivobook Gaming Core i7 10th Gen - (16 GB...    ₹67,990    4.1
# 9   ASUS ROG Strix G15 Core i7 10th Gen - (16 GB/5...    ₹84,990    4.5
# 10  ASUS ROG Strix G15 Ryzen 7 Octa Core 6800H - (...  ₹1,14,990    4.8
# 11  ASUS ASUS TUF Gaming Ryzen 7 Octa Core 4800H -...    ₹80,990    4.5
# ...

# %%
Laptop["discount"]=laptop_offer

# %%
Laptop
# Out:
#                                                laptop      price rating  \
# 0   ASUS ASUS TUF Gaming A17 Ryzen 7 Octa Core 480...    ₹79,990    4.5
# 1   ASUS ASUS TUF Gaming Core i5 11th Gen - (8 GB/...    ₹75,990    4.5
# 2   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...    ₹59,990    4.5
# 3   ASUS TUF Gaming F15 Core i5 10th Gen - (8 GB/5...    ₹62,800    4.5
# 4   ASUS ROG Strix G15 Ryzen 7 Octa Core 4800H - (...    ₹83,990    4.6
# 5   ASUS ROG Strix G15 Ryzen 9 Octa Core 5900HX - ...  ₹1,35,990    4.1
# 6   ASUS ASUS TUF Dash F15 Core i5 11th Gen - (16 ...    ₹84,990    4.9
# 7             ASUS TUF M3 Wired Optical  Gaming Mouse     ₹1,589    4.7
# 8   ASUS Vivobook Gaming Core i7 10th Gen - (16 GB...    ₹67,990    4.1
# 9   ASUS ROG Strix G15 Core i7 10th Gen - (16 GB/5...    ₹84,990    4.5
# 10  ASUS ROG Strix G15 Ryzen 7 Octa Core 6800H - (...  ₹1,14,990    4.8
# 11  ASUS ASUS TUF Gaming Ryzen 7 Octa Core 4800H -...    ₹80,990    4.5
# ...

# %%
Laptop.to_csv("C:/Users/faizal ahamed/Downloads/laptop.csv")
